# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# national-history (US)
national_hist = pd.read_csv('national-history.csv')

national_hist['date'] = pd.to_datetime(national_hist['date'])

# reverse order of rows : https://stackoverflow.com/questions/35240528/reverse-dataframes-rows-order-with-pandas
national_hist = national_hist.iloc[::-1]
national_hist
# Out:
#           date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 419 2020-01-13       NaN              0              NaN             NaN
# 418 2020-01-14       NaN              0              NaN             NaN
# 417 2020-01-15       NaN              0              NaN             NaN
# 416 2020-01-16       NaN              0              NaN             NaN
# 415 2020-01-17       NaN              0              NaN             NaN
# ..         ...       ...            ...              ...             ...
# 4   2021-03-03  508665.0           2449          45214.0          9359.0
# 3   2021-03-04  510408.0           1743          45293.0          8970.0
# 2   2021-03-05  512629.0           2221          45373.0          8634.0
# 1   2021-03-06  514309.0           1680          45453.0          8409.0
# 0   2021-03-07  515148.0            839          45475.0          8137.0
#
#      hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# ...

# %%
fig, ax = plt.subplots(figsize=(12,7)) 

ax.plot(national_hist['date'], national_hist['death'])                          

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in U.S.')
ax.set_ylabel('Number of Deaths')

plt.savefig('us_covid.png')

plt.show()

# %%
# Historical Data Worldwide (ECDC)

ecdc = pd.read_csv('data.csv', index_col=0)
ecdc.index = pd.to_datetime(ecdc.index)

ecdc = ecdc.iloc[::-1]
ecdc.rename(columns={'countriesAndTerritories':'countries'}, inplace=True)
ecdc.sort_index(inplace=True)
ecdc
# Out:
#             day  month  year  cases  deaths    countries geoId  \
# dateRep
# 2019-12-31   31     12  2019      0       0         Iran    IR
# 2019-12-31   31     12  2019      0       0     Pakistan    PK
# 2019-12-31   31     12  2019      0       0   Luxembourg    LU
# 2019-12-31   31     12  2019      0       0      Vietnam    VN
# 2019-12-31   31     12  2019      0       0      Belarus    BY
# ...         ...    ...   ...    ...     ...          ...   ...
# 2020-12-14   14     12  2020     30       0         Togo    TG
# 2020-12-14   14     12  2020   1104       6  Puerto_Rico    PR
# 2020-12-14   14     12  2020    357      17      Armenia    AM
# 2020-12-14   14     12  2020      5       0      Iceland    IS
# 2020-12-14   14     12  2020    746       6  Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2019-12-31                  IRN   82913893.0         Asia
# 2019-12-31                  PAK  216565317.0         Asia
# ...

# %%
ecdc = pd.read_csv('data.csv', index_col=0)

# North America
# United States
ecdc_us = ecdc.loc[ecdc['countriesAndTerritories'] == 'United_States_of_America'].copy()
ecdc_us.index = pd.to_datetime(ecdc_us.index)
ecdc_us.sort_index(inplace=True)

# Dominican Republic
ecdc_dr = ecdc.loc[ecdc['countriesAndTerritories'] == 'Dominican_Republic'].copy()
ecdc_dr.index = pd.to_datetime(ecdc_dr.index)
ecdc_dr.sort_index(inplace=True)

# Haiti
ecdc_ht = ecdc.loc[ecdc['countriesAndTerritories'] == 'Haiti'].copy()
ecdc_ht.index = pd.to_datetime(ecdc_ht.index)
ecdc_ht.sort_index(inplace=True)

# %%
# South America
# Brazil
ecdc_bz = ecdc.loc[ecdc['countriesAndTerritories'] == 'Brazil'].copy()
ecdc_bz.index = pd.to_datetime(ecdc_bz.index)
ecdc_bz.sort_index(inplace=True)

# Bolivia
ecdc_bo = ecdc.loc[ecdc['countriesAndTerritories'] == 'Bolivia'].copy()
ecdc_bo.index = pd.to_datetime(ecdc_bo.index)
ecdc_bo.sort_index(inplace=True)

# Ecuador
ecdc_ec = ecdc.loc[ecdc['countriesAndTerritories'] == 'Ecuador'].copy()
ecdc_ec.index = pd.to_datetime(ecdc_ec.index)
ecdc_ec.sort_index(inplace=True)

# %%
# Europe
# Spain
ecdc_sp = ecdc.loc[ecdc['countriesAndTerritories'] == 'Spain'].copy()
ecdc_sp.index = pd.to_datetime(ecdc_sp.index)
ecdc_sp.sort_index(inplace=True)

# UK
ecdc_uk = ecdc.loc[ecdc['countriesAndTerritories'] == 'United_Kingdom'].copy()
ecdc_uk.index = pd.to_datetime(ecdc_uk.index)
ecdc_uk.sort_index(inplace=True)

# Norway
ecdc_no = ecdc.loc[ecdc['countriesAndTerritories'] == 'Norway'].copy()
ecdc_no.index = pd.to_datetime(ecdc_no.index)
ecdc_no.sort_index(inplace=True)

# %%
# Africa
# South Africa
ecdc_sa = ecdc.loc[ecdc['countriesAndTerritories'] == 'South_Africa'].copy()
ecdc_sa.index = pd.to_datetime(ecdc_sa.index)
ecdc_sa.sort_index(inplace=True)

# Egypt
ecdc_eg = ecdc.loc[ecdc['countriesAndTerritories'] == 'Bolivia'].copy()
ecdc_eg.index = pd.to_datetime(ecdc_eg.index)
ecdc_eg.sort_index(inplace=True)

# Nigeria
ecdc_ni = ecdc.loc[ecdc['countriesAndTerritories'] == 'Nigeria'].copy()
ecdc_ni.index = pd.to_datetime(ecdc_ni.index)
ecdc_ni.sort_index(inplace=True)

# %%
# Asia
# Taiwan
ecdc_tw = ecdc.loc[ecdc['countriesAndTerritories'] == 'Taiwan'].copy()
ecdc_tw.index = pd.to_datetime(ecdc_tw.index)
ecdc_tw.sort_index(inplace=True)

# UAE
ecdc_uae = ecdc.loc[ecdc['countriesAndTerritories'] == 'United_Arab_Emirates'].copy()
ecdc_uae.index = pd.to_datetime(ecdc_uae.index)
ecdc_uae.sort_index(inplace=True)

# Laos
ecdc_ls = ecdc.loc[ecdc['countriesAndTerritories'] == 'Laos'].copy()
ecdc_ls.index = pd.to_datetime(ecdc_ls.index)
ecdc_ls.sort_index(inplace=True)

# China
ecdc_ch = ecdc.loc[ecdc['countriesAndTerritories'] == 'China'].copy()
ecdc_ch.index = pd.to_datetime(ecdc_ch.index)
ecdc_ch.sort_index(inplace=True)

# Singapore
ecdc_sg = ecdc.loc[ecdc['countriesAndTerritories'] == 'Singapore'].copy()
ecdc_sg.index = pd.to_datetime(ecdc_sg.index)
ecdc_sg.sort_index(inplace=True)

# %%
# Australia
ecdc_aus = ecdc.loc[ecdc['countriesAndTerritories'] == 'Australia'].copy()
ecdc_aus.index = pd.to_datetime(ecdc_aus.index)
ecdc_aus.sort_index(inplace=True)

# %%
# North America
fig, ax = plt.subplots(figsize=(12,7))
#ax.plot(ecdc_us.index, ecdc_us['deaths'], label='USA')
ax.plot(ecdc_dr.index, ecdc_dr['deaths'], label='Dominican Republic')
ax.plot(ecdc_ht.index, ecdc_ht['deaths'], label='Haiti')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in North America')
ax.set_ylabel('Number of Deaths')

plt.savefig('dr-ht.png', bbox_inches="tight")

plt.legend()
plt.show()

# %%
ecdc_us['growth'] = ecdc_us['deaths'].pct_change() * 100
ecdc_dr['growth'] = ecdc_dr['deaths'].pct_change() * 100
ecdc_ht['growth'] = ecdc_ht['deaths'].pct_change() * 100

# %%
# North America Percent Change
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_us.index, ecdc_us['growth'], label='USA', linestyle='-', marker='o')
ax.plot(ecdc_dr.index, ecdc_dr['growth'], label='Dominican Republic', linestyle='-', marker='o')
ax.plot(ecdc_ht.index, ecdc_ht['growth'], label='Haiti', linestyle='-', marker='o')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in North America')
ax.set_ylabel('Percent Change')

plt.savefig('na_covid_growth.png', bbox_inches="tight")

plt.legend()
plt.show()

# %%
# South America
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_bz.index, ecdc_bz['deaths'], label='Brazil')
ax.plot(ecdc_bo.index, ecdc_bo['deaths'], label='Bolivia')
#ax.plot(ecdc_ec.index, ecdc_ec['deaths'], label='Ecuador')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in South America')
ax.set_ylabel('Number of Deaths')

plt.savefig('bz_bo_covid.png')

plt.legend()
plt.show()

# %%
ecdc_bz['growth'] = ecdc_bz['deaths'].pct_change() * 100
ecdc_bo['growth'] = ecdc_bo['deaths'].pct_change() * 100
ecdc_ec['growth'] = ecdc_ec['deaths'].pct_change() * 100

# %%
# South America Percent Change
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_bz.index, ecdc_bz['growth'], label='Brazil')
ax.plot(ecdc_bo.index, ecdc_bo['growth'], label='Bolivia')
ax.plot(ecdc_ec.index, ecdc_ec['growth'], label='Ecuador')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in South America')
ax.set_ylabel('Percent Change')

plt.savefig('sa_covid_growth.png')

plt.legend()
plt.show()

# %%
# Europe
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_sp.index, ecdc_sp['deaths'], label='Spain')
ax.plot(ecdc_uk.index, ecdc_uk['deaths'], label='UK')
ax.plot(ecdc_no.index, ecdc_no['deaths'], label='Norway')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in Europe')
ax.set_ylabel('Number of Deaths')

plt.savefig('eur_covid.png')

plt.legend()
plt.show()

# %%
ecdc_sp['growth'] = ecdc_sp['deaths'].pct_change() * 100
ecdc_uk['growth'] = ecdc_uk['deaths'].pct_change() * 100
ecdc_no['growth'] = ecdc_no['deaths'].pct_change() * 100

# %%
# Europe
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_sp.index, ecdc_sp['growth'], label='Spain', linestyle='-', marker='o')
ax.plot(ecdc_uk.index, ecdc_uk['growth'], label='UK', linestyle='-', marker='o')
ax.plot(ecdc_no.index, ecdc_no['growth'], label='Norway', linestyle='-', marker='o')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in Europe')
ax.set_ylabel('% Change')

plt.savefig('eur_covid_growth.png')

plt.legend()
plt.show()

# %%
# Africa
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_sa.index, ecdc_sa['deaths'], label='South Africa')
#ax.plot(ecdc_eg.index, ecdc_eg['deaths'], label='Egypt')
ax.plot(ecdc_ni.index, ecdc_ni['deaths'], label='Nigeria')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in Africa')
ax.set_ylabel('Number of Deaths')

plt.savefig('sa-ni_covid.png')

plt.legend()
plt.show()

# %%
ecdc_sa['growth'] = ecdc_sa['deaths'].pct_change() * 100
ecdc_eg['growth'] = ecdc_eg['deaths'].pct_change() * 100
ecdc_ni['growth'] = ecdc_ni['deaths'].pct_change() * 100

# %%
# Africa
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_sa.index, ecdc_sa['growth'], label='South Africa')
ax.plot(ecdc_eg.index, ecdc_eg['growth'], label='Egypt')
ax.plot(ecdc_ni.index, ecdc_ni['growth'], label='Nigeria')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in Africa')
ax.set_ylabel('% Change')

plt.savefig('afr_covid_growth.png')

plt.legend()
plt.show()

# %%
# Asia
fig, ax = plt.subplots(figsize=(12,7))
#ax.plot(ecdc_tw.index, ecdc_tw['deaths'], label='Taiwan')
ax.plot(ecdc_uae.index, ecdc_uae['deaths'], label='UAE')
#ax.plot(ecdc_ls.index, ecdc_ls['deaths'], label='Laos')
#ax.plot(ecdc_ch.index, ecdc_ch['deaths'], label='China')
ax.plot(ecdc_sg.index, ecdc_sg['deaths'], label='Singapore')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in Asia')
ax.set_ylabel('Number of Deaths')

plt.savefig('ua_sg_covid.png')

plt.legend()
plt.show()

# %%
ecdc_tw['growth'] = ecdc_tw['deaths'].pct_change() * 100
ecdc_uae['growth'] = ecdc_uae['deaths'].pct_change() * 100
ecdc_ls['growth'] = ecdc_ls['deaths'].pct_change() * 100
ecdc_ch['growth'] = ecdc_ch['deaths'].pct_change() * 100
ecdc_sg['growth'] = ecdc_sg['deaths'].pct_change() * 100

# %%
# Asia % ∆
fig, ax = plt.subplots(figsize=(12,7))
#ax.plot(ecdc_tw.index, ecdc_tw['growth'], label='Taiwan')
ax.plot(ecdc_uae.index, ecdc_uae['growth'], label='UAE')
#ax.plot(ecdc_ls.index, ecdc_ls['growth'], label='Laos')
ax.plot(ecdc_ch.index, ecdc_ch['growth'], label='China')
ax.plot(ecdc_sg.index, ecdc_sg['growth'], label='Singapore')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in Asia')
ax.set_ylabel('% Change')

plt.savefig('asia_covid_growth.png')

plt.legend()
plt.show()

# %%
# Australia
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_tw.index, ecdc_tw['deaths'], label='Australia')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Rates in Australia')
ax.set_ylabel('Number of Deaths')

plt.savefig('aus_covid.png')

plt.legend()
plt.show()

# %%
# Australia
fig, ax = plt.subplots(figsize=(12,7))
ax.plot(ecdc_aus.index, ecdc_aus['deaths'].pct_change() * 100, linestyle='-', marker='o')

# Despine
sns.despine(ax = ax)                             

# Label 
ax.set_title('COVID-19 Infection Growth Rates in Australia')
ax.set_ylabel('% Change')

plt.savefig('aus_covid_growth.png')

plt.show()
